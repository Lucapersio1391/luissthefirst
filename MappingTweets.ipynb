# %%
import json
import pandas as pd

# %%
df = pd.read_json(r"C:\Users\lucar\AppData\Roaming\nltk_data/corpora/twitter_samples/tweets.20150430-223406.json", lines=True, orient='records')

# %%
df.head()
# Out:
#    contributors coordinates          created_at  \
# 0           NaN        None 2015-04-30 21:34:06
# 1           NaN        None 2015-04-30 21:34:06
# 2           NaN        None 2015-04-30 21:34:06
# 3           NaN        None 2015-04-30 21:34:06
# 4           NaN        None 2015-04-30 21:34:07
#
#                                             entities  \
# 0  {'symbols': [], 'trends': [], 'user_mentions':...
# 1  {'symbols': [], 'trends': [], 'user_mentions':...
# 2  {'media': [{'type': 'photo', 'source_status_id...
# 3  {'media': [{'type': 'photo', 'source_status_id...
# 4  {'media': [{'type': 'photo', 'source_status_id...
#
#                                    extended_entities  favorite_count  \
# 0                                                NaN               0
# 1                                                NaN               0
# 2  {'media': [{'type': 'photo', 'source_status_id...               0
# 3  {'media': [{'type': 'photo', 'source_status_id...               0
# 4  {'media': [{'type': 'photo', 'source_status_id...               0
#
#    favorited filter_level   geo                  id  \
# 0      False          low  None  593891099434983425
# 1      False          low  None  593891099548094465
# 2      False          low  None  593891099388846080
# 3      False          low  None  593891100429045760
# 4      False          low  None  593891100768784384
#
#                          ...                          place  \
# 0                        ...                           None
# 1                        ...                           None
# 2                        ...                           None
# 3                        ...                           None
# 4                        ...                           None
#
#   possibly_sensitive  retweet_count  retweeted  \
# 0              False              0      False
# 1              False              0      False
# 2              False              0      False
# 3              False              0      False
# 4              False              0      False
#
#                                     retweeted_status  \
# 0  {'in_reply_to_status_id': None, 'contributors'...
# 1                                                NaN
# 2  {'in_reply_to_status_id': None, 'contributors'...
# 3  {'in_reply_to_status_id': None, 'contributors'...
# 4  {'in_reply_to_status_id': None, 'contributors'...
#
#                                               source  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...
# 1  <a href="http://dlvr.it" rel="nofollow">dlvr.i...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://tapbots.com/tweetbot" rel="nof...
#
#                                                 text            timestamp_ms  \
# 0  RT @KirkKus: Indirect cost of the UK being in ... 2015-04-30 21:34:06.725
# 1  VIDEO: Sturgeon on post-election deals http://... 2015-04-30 21:34:06.752
# 2  RT @LabourEoin: The economy was growing 3 time... 2015-04-30 21:34:06.714
# 3  RT @GregLauder: the UKIP east lothian candidat... 2015-04-30 21:34:06.962
# 4  RT @thesundaypeople: UKIP's housing spokesman ... 2015-04-30 21:34:07.043
#
#    truncated                                               user
# 0      False  {'statuses_count': 74617, 'id_str': '107794703...
# 1      False  {'statuses_count': 126843, 'id_str': '55742250...
# 2      False  {'statuses_count': 4571, 'id_str': '3006692193...
# 3      False  {'statuses_count': 7119, 'id_str': '455154030'...
# 4      False  {'statuses_count': 3543, 'id_str': '187547338'...
#
# [5 rows x 27 columns]

# %%
df = df.assign(dtime = pd.to_datetime(df.created_at))

# %%
import collections

# %%
df1h = df[df.dtime.dt.hour == 21]
df2h = df[df.dtime.dt.hour == 22]

# %%
dictnt = collections.Counter(list(df1h.dtime.dt.minute))

# %%
dfc = pd.DataFrame.from_dict(dictnt,orient='index')

# %%
dfc.columns = ['counts']

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from bs4 import BeautifulSoup

# %%
sources_simplified = []
for line in list(df.source):
    soup = BeautifulSoup(line,'lxml')
    f = soup.findAll('a')
    
    sources_simplified.append(f[0].text)
    #break

# %%
cnt = collections.Counter(sources_simplified)

# %%
dfsource = pd.DataFrame.from_dict(cnt,orient='index')

# %%
dfsource.head()
# Out:
#                         0
# Twitter Web Client   4632
# dlvr.it               190
# Twitter for Android  3421
# Twitter for iPhone   5743
# Tweetbot for iΟS      123

# %%
df = df.assign(source_s = sources_simplified)

# %%
dfIphone = df[df.source_s == 'Twitter for iPhone']

# %%
locations =  []
for l in list(dfIphone['user']):
    #print(l['location'])
    locations.append(l['location'])

# %%
from geopy.geocoders import Nominatim,Bing
geolocator = Nominatim()

BING_KEY = "AkShmvwOpN3-6uU4fqj9peZ_0SLyV7zI6Q69dZ1LT6OPpBgIRia2IIWae-45w-x4"
geolocator = Bing(BING_KEY)

def getCoords(location):
    try:
        locx = geolocator.geocode(location)
        return locx.latitude, locx.longitude
    except:
        return 0., 0.
# Out:
# C:\Users\lucar\Anaconda3\lib\site-packages\geopy\geocoders\osm.py:138: UserWarning: Using Nominatim with the default "geopy/1.16.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning

# %%
import time

# %%
import numpy as np

# %%
np.random.uniform(0.1,0.3)
# Out:
# 0.17275141952783613

# %%
popups = {}
idx = 0
for location in locations:
    if(location != ''):
        popups[location] = idx
    idx += 1

# %%
popus = df.iloc[list(popups.values())].text

# %%
coordDictionary = {}
idx = 0
for location in locations:
    if(location != ''):
        coords = getCoords(location)
        coordDictionary[location] = coords
        print(location, coords)
    time.sleep(np.random.uniform(0.1,0.3))
    
    if(idx > 50):
        break
        
    idx += 1
# Out:
# chesterfield (38.6536598205566, -90.5531768798828)
# Lewisham, London (51.4591598510742, -0.0121299996972084)
# glasgow (55.8578300476074, -4.24250984191895)
# Madrid (40.420280456543, -3.70577001571655)
# London / Surrey (51.506420135498, -0.127210006117821)
# Liverpool (53.4100914001465, -2.9784300327301)
# London (51.506420135498, -0.127210006117821)
# scotland (56.690372467041, -4.04402112960815)
# The Old School House (47.9014282226562, 1.90497994422913)
# west of the wash/north of IoW (42.0746994018555, -93.4999694824219)
# United Kingdom (53.9438323974609, -2.55056405067444)
# West Midlands. UK.  (52.4700012207031, -2.28999996185303)
# Camblesforth, North Yorkshire (53.7265090942383, -1.01749694347382)
# London (51.506420135498, -0.127210006117821)
# Woking and Scunthorpe (53.5864906311035, -0.651799976825714)
# Whitstable (51.3623085021973, 1.02664005756378)
# south-east London (51.4900016784668, -0.0697610005736351)
# Upper Gwladys Optimist (42.8856811523438, -79.7607498168945)
# The Land of Dragons!...Wales❤️ (0.0, 0.0)
# England (52.598876953125, -1.46688103675842)
# Peckham (51.4721794128418, -0.0677900016307831)
# West Midlands. UK.  (52.4700012207031, -2.28999996185303)
# London (51.506420135498, -0.127210006117821)
# Upper Gwladys Optimist (42.8856811523438, -79.7607498168945)
# The Land of Dragons!...Wales❤️ (52.3250732421875, -3.79941296577454)
# Cambridge (52.2098007202148, 0.111469998955727)
# London / Paris & other places (51.50824, -0.13351)
# North East Somerset  (51.12548828125, -2.99653196334839)
# Milton Keynes, England (52.0436210632324, -0.754670023918152)
# United Kingom (53.9438323974609, -2.55056405067444)
# UK (53.9438323974609, -2.55056405067444)
# Bristol, UK (51.4537887573242, -2.59168004989624)
# London (51.506420135498, -0.127210006117821)
# Royal Leamington Spa (52.2891998291016, -1.5353000164032)
# Troon (55.5462493896484, -4.65369987487793)
# Yeovil (50.9486999511719, -2.63947010040283)
# London and Surrey (51.506420135498, -0.127210006117821)
# Burton on Trent (52.8044395446777, -1.64790999889374)
# England's green& pleasant land (52.598876953125, -1.46688103675842)
# Michael ❤️ (35.846118927002, -80.3311309814453)
# Glasgow (55.8578300476074, -4.24250984191895)
# Wiltshire (51.2978553771973, -1.95354604721069)
# london (51.506420135498, -0.127210006117821)

# %%
idx = 0
cnew = []
for c in coordDictionary.values():
    p = popus.iloc[idx]
    cnew.append(p)
    idx += 1

# %%
clist = []
for k, c in coordDictionary.items():
    if(c[0] != 0.0):
        #print(c)
        clist.append(c)

# %%
import folium

# %%
m = folium.Map(location=[55.5074, 0.1278],zoom_start=5)

i = 0

for c in clist:
    folium.Marker(location=[c[0],c[1]]).add_to(m)
    i += 1

# %%
dfsource.columns = ['counts']
dfsource.sort_values(by='counts',ascending=False)
# Out:
#                               counts
# Twitter for iPhone              5743
# Twitter Web Client              4632
# Twitter for Android             3421
# Twitter for iPad                2568
# Twitter for Android Tablets      861
# Twitter for Windows Phone        427
# twitterfeed                      382
# TweetDeck                        306
# dlvr.it                          190
# Mobile Web (M5)                  172
# IFTTT                            161
# Tweetbot for iΟS                 123
# Twitter for BlackBerry            86
# Twitter for BlackBerry®           62
# Echofon                           61
# Facebook                          53
# Twitter for Mac                   51
# TweetCaster for Android           49
# Hootsuite                         46
# iOS                               35
# Google                            35
# RoundTeam                         31
# Mobile Web (M2)                   26
# Tweetbot for Mac                  24
# Twitterrific                      23
# TweetAdder v4                     22
# SocialOomph                       21
# Lissted                           19
# Plume for Android                 18
# Mobile Web                        18
# ...                              ...
# Cityvibe San Fran                  1
# qplog                              1
# Zipped News                        1
# WeLinkNews                         1
# Haberwp                            1
# Twitt Manager                      1
# twiDAQ                             1
# techmixx                           1
# Tweetium for Windows               1
# Poshmark                           1
# UKIPRR                             1
# Dabr                               1
# Kindle                             1
# Dabr.eu - latest @Dabr build       1
# Sneap Nederland                    1
# UK Newz                            1
# iScore Baseball                    1
# sievenews                          1
# UKPoliticsRR                       1
# Win the Customer                   1
# pointys messages                   1
# rustudio-ruana.ru                  1
# Falcon Pro                         1
# yoono                              1
# AutoPosts_UniversalPosts           1
# LiveJournal.com                    1
# Let's Help Ebayers Phil            1
# Samsung Mobile                     1
# Fastpages                          1
# KingstnThamesRR                    1
#
# [162 rows x 1 columns]

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
